# %%
from nilearn import datasets
dataset = datasets.fetch_atlas_harvard_oxford('cort-maxprob-thr25-2mm')
atlas_filename = dataset.maps
labels = dataset.labels
# Out:
# /home/surprise/anaconda3/envs/YAD_STAGIN/lib/python3.8/site-packages/nilearn/datasets/__init__.py:87: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   warn("Fetchers from the nilearn.datasets module will be "
# Dataset created in /home/surprise/nilearn_data/fsl
#
# Downloading data from http://www.nitrc.org/frs/download.php/9902/HarvardOxford.tgz ...
# Downloaded 25600000 of 25716861 bytes (99.5%,    0.3s remaining) ...done. (65 seconds, 1 min)
# Extracting data from /home/surprise/nilearn_data/fsl/245b1ae3f43e3ea47e2ed9f438694f4a/HarvardOxford.tgz..... done.

# %%
from nilearn import plotting
plotting.plot_roi(atlas_filename)
